# %% [markdown]
# <a href="https://colab.research.google.com/github/msymhkr/mainopen/blob/main/M6P.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <<Number Prediction - Method 1>>

# %%
# Method 1
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd

file_path = "/content/Colab - Final Mark Six Result List 2024 - 2003.csv"
# file_path = "/content/sample_data/Colab - Final Mark Six Result List 2024 - 2003.csv"
data = pd.read_csv(file_path)
data.to_csv(file_path, index= False, header= True)
data = data.drop('Volume', axis=1)
data1 = data.drop('Date', axis=1)
# data.drop(data.tail(2570).index, inplace=True)

# normalize array
max_number = np.max(data1)
t_data = np.divide(data1, max_number)
t_data = t_data.to_numpy()

time_steps = 1  # each row as one time step
num_features = t_data.shape[1]  # Number of features, in our case 7
X_train = np.reshape(t_data, (t_data.shape[0], time_steps, num_features))
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(time_steps, num_features)))
model.add(Dense(4))
model.compile(optimizer='adam', loss='mse')

print("sssssssssssssss")
# print(t_data(type))
print(t_data[0:, 0:4])
model.fit(X_train, t_data[0:, 0:4], epochs=100, batch_size=32)
model.save('M6Predict-1.h5')

# example_input: replace it with real input data
example_input = np.array([[23, 17, 34, 1, 22, 30]])
normalized_input = np.divide(example_input, max_number)
X_predict = np.reshape(normalized_input, (time_steps, num_features))
# making predictions
predicted_numbers = model.predict(X_predict)
# denormalizing and rounding the numbers
actual_predictions = np.round(predicted_numbers * max_number).astype(int)
# the first 4 numbers are our predictions
predicted_lottery_numbers = actual_predictions[0, :4]
print("Predicted lottery numbers:", predicted_lottery_numbers)
# Out:
# sssssssssssssss
# [[0.10204082 0.12244898 0.32653061 0.46938776]
#  [0.18367347 0.20408163 0.24489796 0.53061224]
#  [0.16326531 0.34693878 0.42857143 0.44897959]
#  ...
#  [0.10204082 0.26530612 0.44897959 0.55102041]
#  [0.16326531 0.28571429 0.40816327 0.57142857]
#  [0.02040816 0.06122449 0.14285714 0.3877551 ]]
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1090
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0098
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0061
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0034
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6339e-04
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4334e-04
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8206e-04
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6565e-04
# Epoch 12/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7851e-04
# Epoch 13/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2345e-04
# Epoch 14/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6837e-05
# Epoch 15/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.2786e-05
# Epoch 16/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6417e-05
# Epoch 17/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9942e-05
# Epoch 18/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8036e-05
# Epoch 19/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7954e-05
# Epoch 20/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.1316e-05
# Epoch 21/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9118e-05
# Epoch 22/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9270e-05
# Epoch 23/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.8137e-05
# Epoch 24/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0713e-05
# Epoch 25/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9701e-05
# Epoch 26/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8274e-05
# Epoch 27/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6832e-05
# Epoch 28/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4966e-05
# Epoch 29/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5997e-05
# Epoch 30/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2749e-05
# Epoch 31/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9890e-05
# Epoch 32/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9434e-05
# Epoch 33/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7889e-05
# Epoch 34/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5724e-05
# Epoch 35/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2069e-05
# Epoch 36/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9891e-05
# Epoch 37/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8597e-05
# Epoch 38/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8745e-05
# Epoch 39/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7725e-05
# Epoch 40/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6581e-05
# Epoch 41/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8031e-05
# Epoch 42/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5567e-05
# Epoch 43/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3135e-05
# Epoch 44/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4440e-05
# Epoch 45/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1915e-05
# Epoch 46/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0890e-05
# Epoch 47/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1118e-05
# Epoch 48/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9810e-05
# Epoch 49/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7690e-05
# Epoch 50/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7919e-05
# Epoch 51/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6474e-05
# Epoch 52/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4788e-05
# Epoch 53/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4410e-05
# Epoch 54/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4899e-05
# Epoch 55/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4259e-05
# Epoch 56/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3108e-05
# Epoch 57/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2419e-05
# Epoch 58/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2194e-05
# Epoch 59/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0817e-05
# Epoch 60/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1566e-05
# Epoch 61/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2195e-06
# Epoch 62/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6216e-06
# Epoch 63/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8563e-06
# Epoch 64/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5834e-06
# Epoch 65/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.4928e-06
# Epoch 66/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.1325e-06
# Epoch 67/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2364e-06
# Epoch 68/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1391e-06
# Epoch 69/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9815e-06
# Epoch 70/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.0246e-06
# Epoch 71/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0992e-06
# Epoch 72/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3471e-06
# Epoch 73/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3357e-06
# Epoch 74/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0880e-06
# Epoch 75/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7855e-06
# Epoch 76/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8823e-06
# Epoch 77/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3661e-06
# Epoch 78/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4852e-06
# Epoch 79/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0955e-06
# Epoch 80/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9097e-06
# Epoch 81/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8924e-06
# Epoch 82/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3940e-06
# Epoch 83/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0135e-06
# Epoch 84/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2133e-06
# Epoch 85/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5564e-06
# Epoch 86/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1155e-06
# Epoch 87/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2104e-06
# Epoch 88/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8619e-06
# Epoch 89/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7447e-06
# Epoch 90/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3358e-06
# Epoch 91/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6086e-06
# Epoch 92/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7657e-06
# Epoch 93/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2932e-06
# Epoch 94/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8589e-06
# Epoch 95/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2170e-06
# Epoch 96/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5788e-06
# Epoch 97/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1065e-06
# Epoch 98/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7311e-06
# Epoch 99/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0197e-06
# Epoch 100/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2323e-06
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-f465f948e47d> in <cell line: 38>()
#      36 example_input = np.array([[23, 17, 34, 1, 22, 30]])
#      37 normalized_input = np.divide(example_input, max_number)
# ---> 38 X_predict = np.reshape(normalized_input, (time_steps, num_features))
#      39 # making predictions
#      40 predicted_numbers = model.predict(X_predict)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     283            [5, 6]])
#     284     """
# --> 285     return _wrapfunc(a, 'reshape', newshape, order=order)
#     286
#     287
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      57
#      58     try:
# ---> 59         return bound(*args, **kwds)
#      60     except TypeError:
#      61         # A TypeError occurs if the object does have such a method in its
#
# ValueError: cannot reshape array of size 6 into shape (1,7)

# %%
# Method 2 (incomplete)
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

file_path = "/content/Colab - Final Mark Six Result List 2024 - 2003.csv"
# file_path = "/content/sample_data/Colab - Final Mark Six Result List 2024 - 2003.csv"
data3 = pd.read_csv(file_path)
data2 = data3.drop('Volume', axis=1)
data = data2.drop('Date', axis=1)

scaler = StandardScaler().fit(data.values)
transformed_dataset = scaler.transform(data.values)
t_data = pd.DataFrame(data=transformed_dataset, index=data.index)
# print(t_data)

train_size = int(len(t_data) * 0.8)
train_data, test_data = t_data[:train_size], t_data[train_size:]

def create_sequences(dt, look_back):
  X, y = [], []
  for i in range(0, (len(dt) - look_back - 1)):
      seq1 = dt[i:(i + look_back)]
      X.append(seq1)
      seq2 = dt[(i + look_back): (i + look_back) + 1]
      y.append(seq2)
  return np.array(X), np.array(y)

look_back = 10
X_train, y_train = create_sequences(train_data, look_back)
X_test, y_test = create_sequences(test_data, look_back)

# print(X_train.shape)
# print(X_train[2])
# X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
# X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
# print(11111)
# print(X_test.shape)

model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 7)))
model.add(Dense(1, activation='sigmoid'))
model.summary()
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)
model.save('M6Predict-2.h5')

train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Train loss: {train_loss}')
print(f'Test loss: {test_loss}')

train_preds = model.predict(X_train)
test_preds = model.predict(X_test)

plt.plot(history.history,
    ['loss', 'val_loss'],
    title='Training & Validation Loss',
    xyLabel=['Epoch', 'Loss'])
plt.plot(history.history,
    ['acc', 'val_acc'],
    title='Training & Validation Accuracy',
    xyLabel=['Epoch', 'Loss'])


example_input = np.array([[23, 17, 34, 1, 22, 30, 47]])
# normalizing and reshaping input data
normalized_input = example_input / max_number
X_predict = np.reshape(normalized_input, (time_steps, num_features))


predicted_numbers = model.predict(0, X_predict)
# denormalizing and rounding the numbers
actual_predictions = np.round(predicted_numbers * max_number).astype(int)
# the first 4 numbers are our predictions
predicted_lottery_numbers = actual_predictions[0, :4]
print("Predicted lottery numbers:", predicted_lottery_numbers)
# Out:
# Exception ignored in: <function _xla_gc_callback at 0x7f1ff0737130>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 96, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_14 (LSTM)                       │ (None, 50)                  │          11,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,651 (45.51 KB)
#  Trainable params: 11,651 (45.51 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 2445/2445 - 7s - 3ms/step - acc: 0.0000e+00 - loss: 1.0045
# Epoch 2/100
# 2445/2445 - 10s - 4ms/step - acc: 0.0000e+00 - loss: 0.9973
# Epoch 3/100
# 2445/2445 - 10s - 4ms/step - acc: 0.0000e+00 - loss: 0.9973
# Epoch 4/100
# 2445/2445 - 11s - 4ms/step - acc: 0.0000e+00 - loss: 0.9974
# Epoch 5/100
# 2445/2445 - 10s - 4ms/step - acc: 0.0000e+00 - loss: 0.9973
# Epoch 6/100
# 2445/2445 - 11s - 5ms/step - acc: 0.0000e+00 - loss: 0.9973
# Epoch 7/100
# 2445/2445 - 8s - 3ms/step - acc: 0.0000e+00 - loss: 0.9973
# Epoch 8/100
# 2445/2445 - 10s - 4ms/step - acc: 0.0000e+00 - loss: 0.9973
# Epoch 9/100
# 2445/2445 - 10s - 4ms/step - acc: 0.0000e+00 - loss: 0.9973
# Epoch 10/100
# 2445/2445 - 11s - 4ms/step - acc: 0.0000e+00 - loss: 0.9973
# Epoch 11/100
# 2445/2445 - 7s - 3ms/step - acc: 0.0000e+00 - loss: 0.9973
